# %% [markdown]
# # Project: FIFA 21 Players Data Analysis and Visualization

# %% [markdown]
# **Instructions for Students:**
#
# Please carefully follow these steps to complete and submit your assignment:
#
# 1. **Completing the Assignment**: You are required to work on and complete all tasks in the provided assignment. Be disciplined and ensure that you thoroughly engage with each task.
#
# 2. **Creating a Google Drive Folder**: Each of you must create a new folder on your Google Drive. This will be the repository for all your completed assignment files, aiding you in keeping your work organized and accessible.
#
# 3. **Uploading Completed Assignment**: Upon completion of your assignment, make sure to upload all necessary files, involving codes, reports, and related documents into the created Google Drive folder. Save this link in the 'Student Identity' section and also provide it as the last parameter in the `submit` function that has been provided.
#
# 4. **Sharing Folder Link**: You're required to share the link to your assignment Google Drive folder. This is crucial for the submission and evaluation of your assignment.
#
# 5. **Setting Permission toPublic**: Please make sure your Google Drive folder is set to public. This allows your instructor to access your solutions and assess your work correctly.
#
# Adhering to these procedures will facilitate a smooth assignment process for you and the reviewers.

# %% [markdown]
# **Description:**
#
# Welcome to this data analysis and visualization assignment! In this assignment, we will be exploring the 'FIFA 21 Players' dataset which comprises a rich variety of information about soccer players from around the world. The data extracted are in 'csv' file format.
#
# Your task is to clean and prepare the data for analysis, and then leverage your data visualization skills to uncovers insights about FIFA 21 players, teams, and overall value and wage dynamics.
#
# Here are your tasks outlined in detail:
#
# 1. **Data Cleaning**: The initial dataset contains some unnecessary and redundant information. Your first task is to clean and prepare it for analysis. In doing so:
#     - Remove the 'Unnamed: 0' column from the dataset.
#     - Removing the Newline Characters.
#     - Look for columns which contain star ('★') characters. Remove these characters from all such columns.
#     - Fill in the missing values using an appropriate method.
#     - In the 'Value', 'Wage', and 'Release Clause' columns, remove the '€', 'K', and 'M' characters and convert the currency value to 'int'. For eg, "M" in value column is Million, so multiply the row values by 1,000,000, etc.
#
# 2. **Data Visualization**: After the data has been cleaned and prepared, use appropriate data visualization methods to represent the data as follows:
#     - Create a Pie Chart to display the preferred foot ('Left' or 'Right') among the FIFA 21 players.
#     - Use a Bar Plot to represent the top 3 FIFA 21 players.
#     - Visualize the best FIFA teams from 100 players based on the 'OVA' score using a Bar Plot.
#     - Use a Bar Plot to display the top 10 most valuable FIFA teams.
#     - Create a Scatter Plot to show players who are highly valuable but still underpaid.
#
# Ensure all plots are fully labeled with titles, x and y variables, and a legend if necessary.
#
# Remember, the goal of this assignment is not just about getting the right answer but also about presenting your findings in a clear, logical, and visually appealing manner. Good luck and enjoy the analysis!

# %% [markdown]
# **Note for Students:**
#
# Please bear in mind that, although you may tackle most of the assignment problems in any order you prefer, **tasks 9 and 10 require that you complete task 5 first**. This is due to the dependencies these tasks have on the cleaned and prepared financial data ('Value' and 'Wage' columns) from task 5.
#
# **You will not be able to accurately complete tasks 9 and 10 without having concluded task 5**. Conversely, other tasks in this assignment do not have such interdependencies and can be completed independently.
#
# Happy analyzing!

# %% [markdown]
# ## Student Identity

# %%
# @title #### Student Identity
student_id = "" # @param {type:"string"}
name = "Nur Ikhsan Wibowo" # @param {type:"string"}
drive_link = ""  # @param {type:"string"}

# %% [markdown]
# ## Import package

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# !pip install rggrader
from rggrader import submit
from rggrader import submit_image
# Out:
# Collecting rggrader
#   Downloading rggrader-0.1.6-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from rggrader) (2.31.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from rggrader) (1.5.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rggrader) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rggrader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rggrader) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->rggrader) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->rggrader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->rggrader) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->rggrader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->rggrader) (2023.11.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->rggrader) (1.16.0)
# Installing collected packages: rggrader
# Successfully installed rggrader-0.1.6

# %% [markdown]
# ## Read file

# %%
url = 'https://storage.googleapis.com/rg-ai-bootcamp/assignment-1/fifa21_raw_data.csv'
fifa_df = pd.read_csv(url, low_memory=False)
#set maximal columns displayed
pd.set_option('display.max_columns', 35)
fifa_df.head()
# Out:
#    Unnamed: 0      ID               Name                      LongName  \
# 0           0  158023           L. Messi                  Lionel Messi
# 1           1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2           2  200389           J. Oblak                     Jan Oblak
# 3           3  192985       K. De Bruyne               Kevin De Bruyne
# 4           4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#   Nationality  Age  ↓OVA  POT                         Club     Contract  \
# 0   Argentina   33    93   93         \n\n\n\nFC Barcelona  2004 ~ 2021
# 1    Portugal   35    92   92             \n\n\n\nJuventus  2018 ~ 2022
# 2    Slovenia   27    91   93      \n\n\n\nAtlético Madrid  2014 ~ 2023
# 3     Belgium   29    91   91      \n\n\n\nManchester City  2015 ~ 2023
# 4      Brazil   28    91   91  \n\n\n\nParis Saint-Germain  2017 ~ 2022
#
#     Positions Height Weight Preferred Foot  BOV Best Position        Joined  \
# 0  RW, ST, CF  170cm   72kg           Left   93            RW   Jul 1, 2004
# 1      ST, LW  187cm   83kg          Right   92            ST  Jul 10, 2018
# 2          GK  188cm   87kg          Right   91            GK  Jul 16, 2014
# 3     CAM, CM  181cm   70kg          Right   91           CAM  Aug 30, 2015
# 4     LW, CAM  175cm   68kg          Right   91            LW   Aug 3, 2017
#
#   Loan Date End    Value   Wage Release Clause  Total Stats  Base Stats  W/F  \
# 0           NaN  €103.5M  €560K        €138.4M         2231         466  4 ★
# 1           NaN     €63M  €220K         €75.9M         2221         464  4 ★
# 2           NaN    €120M  €125K        €159.4M         1413         489  3 ★
# 3           NaN    €129M  €370K          €161M         2304         485  5 ★
# 4           NaN    €132M  €270K        €166.5M         2175         451  5 ★
#
#    SM     A/W     D/W   IR  PAC  SHO  PAS  DRI  DEF  PHY Hits
# 0  4★  Medium     Low  5 ★   85   92   91   95   38   65  771
# 1  5★    High     Low  5 ★   89   93   81   89   35   77  562
# 2  1★  Medium  Medium  3 ★   87   92   78   90   52   90  150
# 3  4★    High    High  4 ★   76   86   93   88   64   78  207
# 4  5★    High  Medium  5 ★   91   85   86   94   36   59  595

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# **Task 1: Removing the 'Unnamed: 0' Column**
#
# In this first task, you have to deal with unnecessary data in our data set. Specifically, the data set contains a column labeled `Unnamed: 0`, which does not make a significant contribution to our data analysis needs. Your goal is to effectively remove this column from the `FIFA 21 Players` data set. Remember that it is very important to manipulate only the unneeded parts of the data and keep the rest intact.
#
# Please make sure to:
# - Read the CSV file carefully to understand the structure of the data.
# - Identify a suitable method to remove the specified column from the DataFrame.
# - Validate that the column has been removed successfully by inspecting the resulting DataFrame.

# %%
# @title #### 01. Removing the 'Unnamed: 0' Column

# Put your code here:
fifa_df = fifa_df.drop('Unnamed: 0', axis=1, inplace=False)


# ---- End of your code ----

# Submit Method
assignment_id = "00_fifa_21_players_data_analysis_and_visualization"
question_id = "01_removing_the_unnamed_column"
submit(student_id, name, assignment_id, fifa_df.head(1).to_string(), question_id, drive_link)
# Out:
# 'Assignment successfully submitted'

# %%
fifa_df.head(1)
# Out:
#        ID      Name      LongName Nationality  Age  ↓OVA  POT  \
# 0  158023  L. Messi  Lionel Messi   Argentina   33    93   93
#
#                    Club     Contract   Positions Height Weight Preferred Foot  \
# 0  \n\n\n\nFC Barcelona  2004 ~ 2021  RW, ST, CF  170cm   72kg           Left
#
#    BOV Best Position       Joined Loan Date End    Value   Wage  \
# 0   93            RW  Jul 1, 2004           NaN  €103.5M  €560K
#
#   Release Clause  Total Stats  Base Stats  W/F  SM     A/W  D/W   IR  PAC  \
# 0        €138.4M         2231         466  4 ★  4★  Medium  Low  5 ★   85
#
#    SHO  PAS  DRI  DEF  PHY Hits
# 0   92   91   95   38   65  771

# %% [markdown]
# **Task 2: Removing the Newline Characters**
#
# In your second task, you will navigate into deeper waters of data cleaning by removing the newline characters (`\n`) from the dataset. This nuisance feature could occur in various columns and can disrupt accurate data parsing. So, it's an important step to assure the integrity and consistency of our data.
#
# Here are a few tips to guide you on this task:
# - Start by detecting which columns in the 'FIFA 21 Players' dataset contain newline characters
# - Develop a strategy to effectively clean the data by replacing or removing these characters
# - As before, make sure your solution keeps all other aspects of the data untouched
# - Validate your solution by examining the cleaned dataset to ensure no more newline characters exist

# %%
fifa_df.head(1)
# Out:
#        ID      Name      LongName Nationality  Age  ↓OVA  POT  \
# 0  158023  L. Messi  Lionel Messi   Argentina   33    93   93
#
#                    Club     Contract   Positions Height Weight Preferred Foot  \
# 0  \n\n\n\nFC Barcelona  2004 ~ 2021  RW, ST, CF  170cm   72kg           Left
#
#    BOV Best Position       Joined Loan Date End    Value   Wage  \
# 0   93            RW  Jul 1, 2004           NaN  €103.5M  €560K
#
#   Release Clause  Total Stats  Base Stats  W/F  SM     A/W  D/W   IR  PAC  \
# 0        €138.4M         2231         466  4 ★  4★  Medium  Low  5 ★   85
#
#    SHO  PAS  DRI  DEF  PHY Hits
# 0   92   91   95   38   65  771

# %%
# @title #### 02. Removing the Newline Characters

# Put your code here:
fifa_df['Club'] = fifa_df['Club'].str.replace('\n','')
#print(fifa_df.head().to_string(index=True, header=True, justify='center'))

# ---- End of your code ----

# Submit Method
assignment_id = "00_fifa_21_players_data_analysis_and_visualization"
question_id = "02_removing_the_newline_characters"
club_col = fifa_df['Club'].head()
submit(student_id, name, assignment_id, club_col.to_string(), question_id, drive_link)
# Out:
# 'Assignment successfully submitted'

# %%
club_col
# Out:
# 0           FC Barcelona
# 1               Juventus
# 2        Atlético Madrid
# 3        Manchester City
# 4    Paris Saint-Germain
# Name: Club, dtype: object

# %% [markdown]
# **Task 3: Removing 'Star' Characters**
#
# In this third task, we will continue with the theme of data cleaning. Your job in this task is to identify and eliminate the 'star' (★) characters from all the columns in the 'FIFA 21 Players' dataset.
#
# As guidelines for you:
# - Begin with an overview of the dataset to identify the columns that contain the 'star' ("*") characters.
# - Formulate a strategy to remove these characters without distorting the remaining data in those columns.
# - Adopt a solution that maintains the integrity of the original data.
# - Finally, validate your solution by examining the cleaned dataset, ensuring that no 'star' characters remain in any columns.

# %%
fifa_df.head(1)
# Out:
#        ID      Name      LongName Nationality  Age  ↓OVA  POT          Club  \
# 0  158023  L. Messi  Lionel Messi   Argentina   33    93   93  FC Barcelona
#
#       Contract   Positions Height Weight Preferred Foot  BOV Best Position  \
# 0  2004 ~ 2021  RW, ST, CF  170cm   72kg           Left   93            RW
#
#         Joined Loan Date End    Value   Wage Release Clause  Total Stats  \
# 0  Jul 1, 2004           NaN  €103.5M  €560K        €138.4M         2231
#
#    Base Stats  W/F  SM     A/W  D/W   IR  PAC  SHO  PAS  DRI  DEF  PHY Hits
# 0         466  4 ★  4★  Medium  Low  5 ★   85   92   91   95   38   65  771

# %%
# @title #### 03. Removing 'Star' Characters

# Put your code here:
fifa_df['W/F'] = fifa_df['W/F'].str.replace('★','')
fifa_df['SM'] = fifa_df['SM'].str.replace('★','')
fifa_df['IR'] = fifa_df['IR'].str.replace('★','')



# ---- End of your code ----

# Submit Method
assignment_id = "00_fifa_21_players_data_analysis_and_visualization"
question_id = "03_removing_star_characters"
star_col = fifa_df[['W/F', 'SM', 'IR']].head()
submit(student_id, name, assignment_id, star_col.to_string(), question_id, drive_link)
# Out:
# 'Assignment successfully submitted'

# %%
star_col
# Out:
#   W/F SM  IR
# 0  4   4  5
# 1  4   5  5
# 2  3   1  3
# 3  5   4  4
# 4  5   5  5

# %% [markdown]
# **Task 4: Filling Missing Values**
#
# In your fourth task, we turn our attention to missing values in our dataset. 'Loan End Date' and 'Hits' columns in the 'FIFA 21 Players' dataset contain some missing entries, which you are tasked with handling. Specifically, you are to fill the missing values in the 'Loan End Date' column with 'Not on Loan', and for the 'Hits' column, use the string 'Unknown'.
#
# Here are your pointers:
# - Start with identifying the missing values in the mentioned columns of 'FIFA 21 Players' dataset.
# - Apply appropriate methods to fill in the missing entries in 'Loan End Date' with 'Not on Loan' and 'Hits' column with 'Unknown', while maintaining the integrity of the existing data.
# - After filling the missing values, verify that these have been correctly filled by inspecting the final state of your DataFrame.

# %%
#total of missing data
total = fifa_df.isnull().sum().sort_values(ascending=False)
total
# Out:
# Loan Date End     17966
# Hits               2595
# PHY                   0
# DEF                   0
# DRI                   0
# PAS                   0
# SHO                   0
# PAC                   0
# Wage                  0
# D/W                   0
# A/W                   0
# SM                    0
# W/F                   0
# Base Stats            0
# Total Stats           0
# Release Clause        0
# IR                    0
# ID                    0
# Name                  0
# Joined                0
# Best Position         0
# BOV                   0
# Preferred Foot        0
# Weight                0
# Height                0
# Positions             0
# Contract              0
# Club                  0
# POT                   0
# ↓OVA                  0
# Age                   0
# Nationality           0
# LongName              0
# Value                 0
# dtype: int64

# %%
# @title #### 04. Filling Missing Values

# Put your code here:
fifa_df = fifa_df.fillna({'Loan Date End': 'Not on Loan', 'Hits': 'Unknown'})


# ---- End of your code ----

# Submit Method
assignment_id = "00_fifa_21_players_data_analysis_and_visualization"
question_id = "04_filling_missing_values"
missing_vals_col = fifa_df[['Loan Date End', 'Hits']].tail()
submit(student_id, name, assignment_id, missing_vals_col.to_string(), question_id, drive_link)
# Out:
# 'Assignment successfully submitted'

# %%
missing_vals_col
# Out:
#       Loan Date End     Hits
# 18974   Not on Loan  Unknown
# 18975   Not on Loan  Unknown
# 18976   Not on Loan  Unknown
# 18977   Not on Loan  Unknown
# 18978   Not on Loan  Unknown

# %%
#total of missing data, check again
total = fifa_df.isnull().sum().sort_values(ascending=False)
total
# Out:
# ID                0
# D/W               0
# Release Clause    0
# Total Stats       0
# Base Stats        0
# W/F               0
# SM                0
# A/W               0
# IR                0
# Name              0
# PAC               0
# SHO               0
# PAS               0
# DRI               0
# DEF               0
# PHY               0
# Wage              0
# Value             0
# Loan Date End     0
# Joined            0
# Best Position     0
# BOV               0
# Preferred Foot    0
# Weight            0
# Height            0
# Positions         0
# Contract          0
# Club              0
# POT               0
# ↓OVA              0
# Age               0
# Nationality       0
# LongName          0
# Hits              0
# dtype: int64

# %% [markdown]
# **Task 5: Cleaning and Converting Financial Data**
#
# In this fifth task, we will focus on improving the readability and workability of the financial data within our dataset. Here, you'll need to identify the 'Value', 'Wage', and 'Release Clause' columns in the 'FIFA 21 Players' dataset, which contain '€', 'K', and 'M' characters.
#
# Here's your course of action:
# - The first step involves eliminating the '€' character in these columns, leaving only numeric values and 'K' or 'M' characters.
# - After that, you're tasked with interpreting the 'K' and 'M' suffixes in these fields as 'x1000' and 'x1,000,000' respectively and subsequently changing the values in light of this new understanding.
# - This interpreted data should then be converted to an 'int' data type, considering that these are financial amounts.
#
# Confirmation of the successful completion of the task can be achieved by validating your dataset once the changes have been made. This task will refine not just your data cleaning capabilities, but also your proficiency in handling and comprehending numerical data.

# %%
total = fifa_df[fifa_df['Value'].str.contains('$')]
total['Value']
# Out:
# 0        €103.5M
# 1           €63M
# 2          €120M
# 3          €129M
# 4          €132M
#           ...
# 18974      €100K
# 18975      €130K
# 18976      €120K
# 18977      €100K
# 18978      €100K
# Name: Value, Length: 18979, dtype: object

# %%
total = fifa_df[fifa_df['Value'].str.contains('M')]
total['Value']
# Out:
# 0        €103.5M
# 1           €63M
# 2          €120M
# 3          €129M
# 4          €132M
#           ...
# 14322        €1M
# 14505        €1M
# 14672        €1M
# 14731        €1M
# 14791        €1M
# Name: Value, Length: 9300, dtype: object

# %%
#df[df.Name.str.contains("\+")]
total = fifa_df[fifa_df['Value'].str.contains('K')]
print(total['Value'])
# Out:
# 1254     €825K
# 1386     €825K
# 1455     €825K
# 1605     €950K
# 1621     €625K
#          ...
# 18974    €100K
# 18975    €130K
# 18976    €120K
# 18977    €100K
# 18978    €100K
# Name: Value, Length: 9431, dtype: object

# %%
# url = 'https://storage.googleapis.com/rg-ai-bootcamp/assignment-1/fifa21_raw_data.csv'
# fifa_df = pd.read_csv(url, low_memory=False)
# #set maximal columns displayed
# pd.set_option('display.max_columns', 35)

# %%
# @title #### 05. Cleaning and Converting Financial Data

# Put your code here:
columns_set = ['Value', 'Wage', 'Release Clause']
for column in columns_set:
    fifa_df[column] = fifa_df[column].str.replace('€', '')
#create list of series from fifa_df
list_value = list(fifa_df['Value'])
list_wage = list(fifa_df['Wage'])
list_release_clause = list(fifa_df['Release Clause'])
set_of_list = [list_value, list_wage, list_release_clause]
#looping to clean, convert type and count data
def clean_and_count(list_of_data):
    for index, value in enumerate (list_of_data):
          if '.' in value:
            if 'K' in value:
              list_of_data[index] = int(float(list_of_data[index].replace('K', '')) * 10 ** 3)
            elif 'M' in value:
              list_of_data[index] = int(float(list_of_data[index].replace('M', '')) * 10 ** 6)
            else:
              list_of_data[index] = int(list_of_data[index])
          else:
            if 'K' in value:
              list_of_data[index] = int(list_of_data[index].replace('K', '')) * 10 ** 3
            elif 'M' in value:
              list_of_data[index] = int(list_of_data[index].replace('M', '')) * 10 ** 6
            else:
              list_of_data[index] = int(list_of_data[index])
    return list_of_data

#input list to clean and count data
for elemen in set_of_list:
  clean_and_count(elemen)

#change original columns data on fifa_df with data from the list
fifa_df['Value'] = np.array(list_value)
fifa_df['Wage'] = np.array(list_wage)
fifa_df['Release Clause'] = np.array(list_release_clause)

# Submit Method
assignment_id = "00_fifa_21_players_data_analysis_and_visualization"
question_id = "05_cleaning_converting_financial_data"
converted_col = fifa_df[['Name', 'Value', 'Wage', 'Release Clause']].head()
submit(student_id, name, assignment_id, converted_col.to_string(), question_id, drive_link)
# Out:
# 'Assignment successfully submitted'

# %%
converted_col
# Out:
#                 Name      Value    Wage  Release Clause
# 0           L. Messi  103500000  560000       138400000
# 1  Cristiano Ronaldo   63000000  220000        75900000
# 2           J. Oblak  120000000  125000       159400000
# 3       K. De Bruyne  129000000  370000       161000000
# 4          Neymar Jr  132000000  270000       166500000

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# **Task 6: Pie Chart Creation - Preferred Foot**
#
# Moving on to the realm of data visualization, your sixth task is to create a Pie Chart that displays the preferred foot ('Left' or 'Right') among the 'FIFA 21 Players'. This visualization would allow us to quickly grasp the proportion of players who prefer using one foot over the other.
#
# Here are your key steps:
# - Identify the respective count of players who prefer 'Left' and 'Right' foot from the dataset.
# - Use this data to create a Pie Chart which accurately represents these proportions.
# - Your Pie Chart should include appropriate labels and title for better readability.

# %%
fifa_df.head(1)
# Out:
#        ID      Name      LongName Nationality  Age  ↓OVA  POT          Club  \
# 0  158023  L. Messi  Lionel Messi   Argentina   33    93   93  FC Barcelona
#
#       Contract   Positions Height Weight Preferred Foot  BOV Best Position  \
# 0  2004 ~ 2021  RW, ST, CF  170cm   72kg           Left   93            RW
#
#         Joined Loan Date End      Value    Wage  Release Clause  Total Stats  \
# 0  Jul 1, 2004   Not on Loan  103500000  560000       138400000         2231
#
#    Base Stats W/F SM     A/W  D/W  IR  PAC  SHO  PAS  DRI  DEF  PHY Hits
# 0         466  4   4  Medium  Low  5    85   92   91   95   38   65  771

# %%
preferred_foot_left = fifa_df[fifa_df['Preferred Foot'].str.contains('Left')]
preferred_foot_left['Preferred Foot'].count()
# Out:
# 4534

# %%
preferred_foot_right = fifa_df[fifa_df['Preferred Foot'].str.contains('Right')]
preferred_foot_right['Preferred Foot'].count()
# Out:
# 14445

# %%
foot_type_counts = fifa_df['Preferred Foot'].value_counts()
foot_type_counts
# Out:
# Right    14445
# Left      4534
# Name: Preferred Foot, dtype: int64

# %%
type(foot_type_counts)
# Out:
# pandas.core.series.Series

# %%
# @title #### 06. Pie Chart Creation - Preferred Foot

# Put your code here:
#Create Series from Preferred Foot column and count the values
foot_type_counts = fifa_df['Preferred Foot'].value_counts()
#get index from Preferred Foot column
foot_type = foot_type_counts.index
#get values from Preferred Foot column
counts = foot_type_counts.values
#create pie chart
plt.pie(counts, labels = foot_type, autopct='%1.1f%%')
#create title
plt.title('Proportion of Preferred Foot Type among FIFA 21 Players')
# save image
plt.savefig('preferred-foot.jpg', format='jpeg')
plt.show()
# ---- End of your code ----

submit_image(student_id, '06. Pie Chart Creation - Preferred Foot', './preferred-foot.jpg')
# Out:
# 'Assignment successfully submitted'

# %% [markdown]
# **Task 7: Bar Plot Creation - Top 3 FIFA 21 Players**
#
# In your seventh task of this assignment, you are to create a bar plot displaying the top 3 FIFA 21 players according to their 'OVA' scores. This graphical representation would help us quickly identify and compare goal averages between the players who have the most influence on the field.
#
# Here's your task outline:
# - From the dataset, extract the top 3 players based on their OVA scores.
# - Now, plot this data using a bar plot with the player names on the x-axis and their respective 'OVA' scores on the y-axis.
# - Make sure your bar plot is correctly labeled with title, x and y variable details, and provides a clear indication of the players and their corresponding scores.

# %%
fifa_df.groupby('Name')['↓OVA'].max().sort_values(ascending=False).head(3)
# Out:
# Name
# L. Messi             93
# Cristiano Ronaldo    92
# K. De Bruyne         91
# Name: ↓OVA, dtype: int64

# %%
# @title #### 07. Bar Plot Creation - Top 3 FIFA 21 Players

# Put your code here:
#filtering top 3 players based on OVA scores
top_3_players_by_OVA = fifa_df.groupby('Name')['↓OVA'].max().sort_values(ascending=False).head(3)
#create X axis by players name
top_3_players_name = top_3_players_by_OVA.index
#create Y axis by OVA score
OVA_score = top_3_players_by_OVA.values
#create bar plot
plt.bar(top_3_players_name, OVA_score)
plt.xlabel('Player_Names')
plt.ylabel('OVA Score')
plt.title('Top 3 FIFA 21 Players')
# Add labels to each bar
for x, y in zip(top_3_players_name, OVA_score):
    plt.text(x, y, str(y), ha='center', va='bottom', fontsize=8, color='red')

plt.savefig('top-3-players.jpg', format='jpeg') # save image
plt.show()
# ---- End of your code ----

submit_image(student_id, '07. Bar Plot Creation - Top 3 FIFA 21 Players', './top-3-players.jpg')
# Out:
# 'Assignment successfully submitted'

# %% [markdown]
# **Task 8: Bar Plot Creation - Best FIFA 21 Teams**
#
# For your eighth task, your goal is to identify and display the best top 10 FIFA teams, as determined by the sum of the 'OVA' scores of their top 100 players. This exercise provides an opportunity to transform raw data into meaningful insights, which can assist in comparing and ranking teams based on cumulative player performance.
#
# Here's your plan of action:
#
# - Start by sorting the dataset in descending order according to the OVA scores. This way, you'll have the players with the highest OVA at the top.
# - After sorting, create a subset of the top 100 players from this sorted DataFrame.
# - Now, you'll need to find out how many of these top 100 players belong to each club. To do this, count the frequency of each club's appearance within those top 100 players and retain the top 10 clubs that have the highest number of top-performing players.
# - Ensure appropriate labelling on your bar plot, including the title as 'The top 100 players based on the overall score play in 10 teams', the x-axis as 'Club', and the y-axis as 'Number of Players' for easy comprehension and interpretation of the data.

# %%
top_100_sorted = fifa_df.sort_values('↓OVA', ascending=False).reset_index(drop=True).head(100)
top_100_sorted
# Out:
#         ID               Name                        LongName Nationality  \
# 0   158023           L. Messi                    Lionel Messi   Argentina
# 1    20801  Cristiano Ronaldo    C. Ronaldo dos Santos Aveiro    Portugal
# 2   200389           J. Oblak                       Jan Oblak    Slovenia
# 3   192985       K. De Bruyne                 Kevin De Bruyne     Belgium
# 4   190871          Neymar Jr      Neymar da Silva Santos Jr.      Brazil
# ..     ...                ...                             ...         ...
# 95  207865         Marquinhos              Marcos Aoás Corrêa      Brazil
# 96  204485          R. Mahrez                    Riyad Mahrez     Algeria
# 97  210243    Ricardo Pereira         Ricardo Barbosa Pereira    Portugal
# 98  231866              Rodri      Rodrigo Hernández Cascante       Spain
# 99  197781               Isco  Francisco Román Alarcón Suárez       Spain
#
#     Age  ↓OVA  POT                 Club     Contract    Positions Height  \
# 0    33    93   93         FC Barcelona  2004 ~ 2021   RW, ST, CF  170cm
# 1    35    92   92             Juventus  2018 ~ 2022       ST, LW  187cm
# 2    27    91   93      Atlético Madrid  2014 ~ 2023           GK  188cm
# 3    29    91   91      Manchester City  2015 ~ 2023      CAM, CM  181cm
# 4    28    91   91  Paris Saint-Germain  2017 ~ 2022      LW, CAM  175cm
# ..  ...   ...  ...                  ...          ...          ...    ...
# 95   26    85   89  Paris Saint-Germain  2013 ~ 2024      CB, CDM  183cm
# 96   29    85   85      Manchester City  2018 ~ 2023       RW, RM  179cm
# 97   26    85   86       Leicester City  2018 ~ 2023           RB  175cm
# 98   24    85   88      Manchester City  2019 ~ 2024      CDM, CM  191cm
# 99   28    84   84          Real Madrid  2013 ~ 2022  CAM, CM, LW  176cm
#
#    Weight Preferred Foot  BOV Best Position        Joined Loan Date End  \
# 0    72kg           Left   93            RW   Jul 1, 2004   Not on Loan
# 1    83kg          Right   92            ST  Jul 10, 2018   Not on Loan
# 2    87kg          Right   91            GK  Jul 16, 2014   Not on Loan
# 3    70kg          Right   91           CAM  Aug 30, 2015   Not on Loan
# 4    68kg          Right   91            LW   Aug 3, 2017   Not on Loan
# ..    ...            ...  ...           ...           ...           ...
# 95   75kg          Right   87            CB  Jul 19, 2013   Not on Loan
# 96   67kg           Left   85            RW  Jul 10, 2018   Not on Loan
# 97   70kg          Right   85            RB   Jun 9, 2018   Not on Loan
# 98   82kg          Right   85           CDM   Jul 4, 2019   Not on Loan
# 99   79kg          Right   84           CAM   Jul 3, 2013   Not on Loan
#
#         Value    Wage  Release Clause  Total Stats  Base Stats W/F SM     A/W  \
# 0   103500000  560000       138400000         2231         466  4   4  Medium
# 1    63000000  220000        75900000         2221         464  4   5    High
# 2   120000000  125000       159400000         1413         489  3   1  Medium
# 3   129000000  370000       161000000         2304         485  5   4    High
# 4   132000000  270000       166500000         2175         451  5   5    High
# ..        ...     ...             ...          ...         ...  .. ..     ...
# 95   66000000  115000        84700000         1962         421  3   3  Medium
# 96   53000000  210000        69400000         2034         430  4   5  Medium
# 97   58000000  120000        78000000         2191         467  4   3    High
# 98   66500000  145000        84700000         2093         448  4   3  Medium
# 99   42500000  210000        64599999         2080         433  3   4  Medium
#
#        D/W  IR  PAC  SHO  PAS  DRI  DEF  PHY Hits
# 0      Low  5    85   92   91   95   38   65  771
# 1      Low  5    89   93   81   89   35   77  562
# 2   Medium  3    87   92   78   90   52   90  150
# 3     High  4    76   86   93   88   64   78  207
# 4   Medium  5    91   85   86   94   36   59  595
# ..     ...  ..  ...  ...  ...  ...  ...  ...  ...
# 95    High  3    72   41   73   70   87   78  211
# 96  Medium  3    83   79   81   90   38   59  112
# 97    High  3    83   66   79   82   81   76  203
# 98    High  2    65   68   77   77   82   79  161
# 99     Low  3    68   75   82   90   59   59  169
#
# [100 rows x 34 columns]

# %%
top_10_club = top_100_sorted.groupby('Club')['Name'].count().sort_values(ascending= False).head(10)
top_10_club
# Out:
# Club
# Liverpool              11
# Real Madrid            10
# FC Barcelona            9
# Manchester City         9
# Juventus                7
# Paris Saint-Germain     7
# FC Bayern München       6
# Chelsea                 5
# Tottenham Hotspur       4
# Inter                   4
# Name: Name, dtype: int64

# %%
# @title #### 08. Bar Plot Creation - Best FIFA 21 Teams

# Put your code here:
#top 100 player based on OVA score
top_100_sorted = fifa_df.sort_values('↓OVA', ascending=False).reset_index(drop=True).head(100)
#count players appearance on club and filter to top 10 club
top_10_club = top_100_sorted.groupby('Club')['Name'].count().sort_values(ascending= False).head(10)
#create x axis
clubs = top_10_club.index
#create y axis
number_of_players = top_10_club.values
#create bar plot
plt.bar(clubs, number_of_players)
plt.xticks(rotation=90, fontsize=10)
plt.xlabel('Clubs')
plt.ylabel('Number of Players')
plt.title('The top 100 players based on the overall score play in 10 teams')
# Add labels to each bar
for x, y in zip(clubs, number_of_players):
    plt.text(x, y, str(y), ha='center', va='bottom', fontsize=8, color='red')
plt.savefig('best-fifa-teams.jpg', format='jpeg') # save image
plt.show()
# ---- End of your code ----

submit_image(student_id, '08. Bar Plot Creation - Best FIFA 21 Teams', './best-fifa-teams.jpg')
# Out:
# 'Assignment successfully submitted'

# %% [markdown]
# **Task 9: Bar Plot Creation - Top 10 Most Valuable FIFA 21 Teams**
#
# In the ninth task, your focus shift towards identifying and displaying the 10 most valuable FIFA teams, determined according to the player with the highest 'Value' among their top 100 players. This gives an indication of the teams that possess high-value players and are thus crucial in the game.
#
# Here's your roadmap to complete the task:
# - Group the data by teams and identify the player with the highest 'Value' for each team among their top 100 players.
# - From this processed data, further identify the top 10 teams with the most valuable players.
# - Now create a bar plot to visualize these top 10 teams and the highest player value for each. Ensure the team names are on the x-axis and player values on the y-axis.
# - Don't forget to appropriately label the plot in terms of title, x and y axis labels, for easy understanding.

# %%
highest_value_top_player_among_clubs = top_100_sorted.groupby('Club')['Value'].max().sort_values(ascending = False).head(10)
highest_value_top_player_among_clubs
top_100_sorted[top_100_sorted['Value'] == 185500000]
# Out:
#        ID       Name       LongName Nationality  Age  ↓OVA  POT  \
# 9  231747  K. Mbappé  Kylian Mbappé      France   21    90   95
#
#                   Club     Contract   Positions Height Weight Preferred Foot  \
# 9  Paris Saint-Germain  2018 ~ 2022  ST, LW, RW  178cm   73kg          Right
#
#    BOV Best Position       Joined Loan Date End      Value    Wage  \
# 9   91            ST  Jul 1, 2018   Not on Loan  185500000  160000
#
#    Release Clause  Total Stats  Base Stats W/F SM   A/W  D/W  IR  PAC  SHO  \
# 9       203100000         2147         466  4   5  High  Low  3    96   86
#
#    PAS  DRI  DEF  PHY  Hits
# 9   78   91   39   76  1.6K

# %%
highest_value_top_player_among_clubs.head()
# Out:
# Club
# Paris Saint-Germain    185500000
# Manchester City        129000000
# Borussia Dortmund      124000000
# Chelsea                121000000
# Liverpool              120500000
# Name: Value, dtype: int64

# %%
# @title #### 09. Bar Plot Creation - Top 10 Most Valuable FIFA 21 Teams

# Put your code here:
#group club based on highest value players for each club from top 100 players
highest_value_top_player_among_clubs = top_100_sorted.groupby('Club')['Value'].sum().sort_values(ascending = False).head(10)
#create x axis
team_names = highest_value_top_player_among_clubs.index
#create y axis
player_values = highest_value_top_player_among_clubs.values
#create bar plot
plt.bar(team_names, player_values / 1000000)
plt.xticks(rotation=90, fontsize=10)
plt.yticks(fontsize=10)
# Set the y-axis ticks to be integers
plt.xlabel('Team Names', fontsize=10)
plt.ylabel('Player Values x 1M', fontsize=10)
plt.title('Top 10 Most Valuable FIFA 21 Teams', fontsize=11)

# Add labels to each bar
for x, y in zip(team_names, player_values / 1000000):
    plt.text(x, y, str(y) + 'M', ha='center', va='bottom', fontsize=8, color='red')

plt.savefig('top-10-valuable-teams.jpg', format='jpeg') # save image
plt.show()
# ---- End of your code ----

submit_image(student_id, '09. Bar Plot Creation - Top 10 Most Valuable FIFA 21 Teams', './top-10-valuable-teams.jpg')
# Out:
# 'Assignment successfully submitted'

# %% [markdown]
# **Task 10: Scatter Plot Creation - High Value, Underpaid Players**
#
# In the tenth and final task of this assignment, your challenge is to create a scatter plot to visualize high value but low paid players. This visualization will help us understand the difference that exists between player values and wages and identify any outliers in the 'Value' and 'Wage' columns.
#
# Here's your guide to tackle this task:
# - Identify the players who have high 'Value' but relatively low 'Wage' in the 'FIFA 21 Players' dataset.
# - Use this filtered data to create a scatter plot, where one axis represents the 'Value' and the other represents the 'Wage' of these players.
# - Remember to correctly label your scatter plot including an appropriate title, x and y axis details, for an accurate understanding of what your plot represents.

# %%
fifa_df[(fifa_df['Value'] == 0) | (fifa_df['Wage'] == 0)]
# Out:
#            ID            Name                          LongName  \
# 289    230347  Welington Dano    Welington Kauê Dano Nascimento
# 292    230225  Juiano Mestres  Juan Everton Mestres de Mesquita
# 369    245299     J. Frendado            Jaime Nicolás Frendado
# 374    245294    J. Serendero          Jorge Ezequiel Serendero
# 375    245308        M. Nérez                Mauro Evidio Nérez
# ...       ...             ...                               ...
# 17220  247059   A. Al Hidhani                    Ali Al Hidhani
# 17343  251734       A. Sanghu                    Anudaan Sanghu
# 17659  251738        M. Chada                   Madanapal Chada
# 17661  251741       E. Suresh                Eelamynthan Suresh
# 18205  251737       J. Mangat                  Jagatjiva Mangat
#
#                 Nationality  Age  ↓OVA  POT     Club Contract    Positions  \
# 289                  Brazil   20    81   81  No Club     Free       LB, LM
# 292                  Brazil   24    81   81  No Club     Free      CB, CDM
# 369                 Uruguay   36    80   80  No Club     Free      CB, CDM
# 374                 Uruguay   32    80   80  No Club     Free           GK
# 375                 Uruguay   32    80   80  No Club     Free       LB, LM
# ...                     ...  ...   ...  ...      ...      ...          ...
# 17220  United Arab Emirates   22    56   64  No Club     Free           RB
# 17343                 India   20    56   56  No Club     Free       RM, CM
# 17659                 India   27    55   55  No Club     Free           ST
# 17661                 India   28    55   55  No Club     Free  RM, CAM, RB
# 18205                 India   26    53   54  No Club     Free           LM
#
#       Height Weight Preferred Foot  BOV Best Position        Joined  \
# 289    178cm   69kg           Left   81            LB   Jan 1, 2019
# 292    181cm   82kg          Right   81            CB   Jan 1, 2019
# 369    181cm   82kg          Right   80            CB  Aug 10, 2018
# 374    190cm   85kg          Right   80            GK  Aug 10, 2018
# 375    178cm   69kg           Left   80            LB  Aug 10, 2018
# ...      ...    ...            ...  ...           ...           ...
# 17220  172cm   67kg          Right   56            RB   Jul 1, 2018
# 17343  168cm   62kg          Right   56            RM  Jul 12, 2019
# 17659  178cm   77kg          Right   57            RM  Jul 12, 2019
# 17661  175cm   73kg           Left   55            RM  Jul 12, 2019
# 18205  171cm   65kg           Left   53            LM  Jul 12, 2019
#
#       Loan Date End  Value  Wage  Release Clause  Total Stats  Base Stats W/F  \
# 289     Not on Loan      0     0               0         2068         436  4
# 292     Not on Loan      0     0               0         2003         413  3
# 369     Not on Loan      0     0               0         1987         408  3
# 374     Not on Loan      0     0               0         1208         435  2
# 375     Not on Loan      0     0               0         2065         436  4
# ...             ...    ...   ...             ...          ...         ...  ..
# 17220   Not on Loan      0     0               0         1443         312  3
# 17343   Not on Loan      0     0               0         1482         308  3
# 17659   Not on Loan      0     0               0         1488         316  1
# 17661   Not on Loan      0     0               0         1626         338  3
# 18205   Not on Loan      0     0               0         1293         275  3
#
#       SM     A/W     D/W  IR  PAC  SHO  PAS  DRI  DEF  PHY     Hits
# 289    4  Medium  Medium  1    79   54   76   78   75   74      172
# 292    2    High  Medium  1    71   61   57   62   82   80       75
# 369    2    High  Medium  1    71   61   57   62   82   75       11
# 374    1  Medium  Medium  1    78   81   77   77   42   80       18
# 375    4  Medium  Medium  1    79   54   75   78   76   74       17
# ...   ..     ...     ...  ..  ...  ...  ...  ...  ...  ...      ...
# 17220  2  Medium  Medium  1    73   33   45   55   51   55  Unknown
# 17343  3  Medium     Low  1    79   42   50   59   29   49  Unknown
# 17659  2    High  Medium  1    67   52   47   61   32   57  Unknown
# 17661  2    High  Medium  1    73   49   51   54   41   70  Unknown
# 18205  2  Medium  Medium  1    68   41   45   58   22   41  Unknown
#
# [248 rows x 34 columns]

# %%
# @title #### 10. Scatter Plot Creation - High Value, Underpaid Players

# Put your code here:
#filtering df
filtered_df = fifa_df[['Name', 'Value', 'Wage']]
#remove players with 0 value and 0 wage
player_with_0_value_wage = filtered_df[(filtered_df['Value'] == 0) | (filtered_df['Wage'] == 0)]
# deleting multiple rows
filtered_df = filtered_df.drop(player_with_0_value_wage.index, axis=0)
#access y axis
values = filtered_df['Value']
#access x axis
wages = filtered_df['Wage']
#create scatter plot
colors = [i for i in range (filtered_df.shape[0])]
plt.scatter(wages / 1000, values / 1000, s = 50, c=colors, cmap = 'rainbow')
plt.colorbar()
plt.xlabel('Wages x 1K ')
plt.ylabel('Values x 1K')
plt.title('Scatter Plot for High Value, Underpaid Players')

plt.savefig('high-value-underpaid-players.jpg', format='jpeg') # save image
plt.show()
# ---- End of your code ----

submit_image(student_id, '10. Scatter Plot Creation - High Value, Underpaid Players', './high-value-underpaid-players.jpg')
# Out:
# 'Assignment successfully submitted'

# %%
filtered_df[filtered_df['Value'] <= filtered_df['Wage']]
# Out:
# Empty DataFrame
# Columns: [Name, Value, Wage]
# Index: []

# %%
mean_value = filtered_df['Value'].mean()
mean_value
# Out:
# 2902996.5809086543

# %%
std_value = filtered_df['Value'].std()
std_value
# Out:
# 7728744.658611512

# %%
lower_limit_value = mean_value - 2 * std_value
upper_limit_value = mean_value + 2 * std_value
lower_limit_value, upper_limit_value
# Out:
# (-12554492.73631437, 18360485.898131676)

# %%
data_without_outliers_value = filtered_df[(filtered_df['Value'] > lower_limit_value) & (filtered_df['Value'] < upper_limit_value)]
data_without_outliers_value
# Out:
#                 Name     Value    Wage
# 14          M. Neuer  17500000  130000
# 24     S. Handanovič  10000000  100000
# 83      Thiago Silva  14500000   95000
# 95          D. Godín  17500000   56000
# 133      Fernandinho  11000000  110000
# ...              ...       ...     ...
# 18974         Xia Ao    100000    1000
# 18975       B. Hough    130000     500
# 18976    R. McKinley    120000     500
# 18977   Wang Zhen'ao    100000    2000
# 18978      Zhou Xiao    100000    1000
#
# [18157 rows x 3 columns]

# %%
mean_wage = filtered_df['Wage'].mean()
std_wage = filtered_df['Wage'].std()
mean_wage, std_wage
# Out:
# (9210.026159841973, 19809.484584480884)

# %%
lower_limit_wage = mean_wage - 2 * std_wage
upper_limit_wage = mean_wage + 2 * std_wage
lower_limit_wage, upper_limit_wage
# Out:
# (-30408.943009119794, 48828.99532880374)

# %%
data_without_outliers_wage_value = data_without_outliers_value[(data_without_outliers_value['Wage'] > lower_limit_wage) & (data_without_outliers_value['Wage'] < upper_limit_wage)]
data_without_outliers_wage_value
# Out:
#                 Name     Value   Wage
# 141      Jesús Navas  15500000  43000
# 180       B. Matuidi  18000000  14000
# 202         E. Džeko  17500000  39000
# 207    J. Vertonghen  17500000  21000
# 208      S. Mandanda   4000000  28000
# ...              ...       ...    ...
# 18974         Xia Ao    100000   1000
# 18975       B. Hough    130000    500
# 18976    R. McKinley    120000    500
# 18977   Wang Zhen'ao    100000   2000
# 18978      Zhou Xiao    100000   1000
#
# [17885 rows x 3 columns]

# %%
# Put your code here:

#access values
values = data_without_outliers_wage_value['Value']
#access wage
wages = data_without_outliers_wage_value['Wage']
#create scatter plot
colors = [i for i in range (data_without_outliers_wage_value.shape[0])]
plt.scatter(wages, values, s = 50, c=colors, cmap = 'rainbow')
plt.colorbar()
plt.xlabel('Wages')
plt.ylabel('Values')
plt.title('Scatter Plot for High Value, Underpaid Players')

plt.savefig('high-value-underpaid-players.jpg', format='jpeg') # save image
plt.show()

# %%
plt.hist(data_without_outliers_wage_value['Value'], bins=20, rwidth=0.8)
plt.xlabel('Value of players')
plt.ylabel('Count')
plt.show()

# %%
import seaborn as sns

# Select specific columns
selected_columns = ['Value', 'Wage']

# Create a pair plot
sns.pairplot(filtered_df[selected_columns])

# Show the plot
plt.show()

# %%
data_without_outliers_wage_value.describe()
# Out:
#               Value          Wage
# count  1.788500e+04  17885.000000
# mean   1.687007e+06   6162.096729
# std    2.388111e+06   8411.657484
# min    9.000000e+03    500.000000
# 25%    4.750000e+05   1000.000000
# 50%    9.000000e+05   3000.000000
# 75%    1.800000e+06   7000.000000
# max    1.800000e+07  48000.000000

# %%
q1 = data_without_outliers_wage_value['Value'].quantile(0.25)
q3 = data_without_outliers_wage_value['Value'].quantile(0.75)
q1, q3
# Out:
# (475000.0, 1800000.0)

# %%
iqr = q3 - q1
iqr
# Out:
# 1325000.0

# %%
lower_limit = q1 - 1.5 * iqr
upper_limit = q3 + 1.5 * iqr
lower_limit, upper_limit
# Out:
# (-1512500.0, 3787500.0)

# %%
low_wage = data_without_outliers_wage_value[data_without_outliers_wage_value['Wage'] < data_without_outliers_wage_value['Wage'].std()]
low_wage_value = low_wage[low_wage['Value'] > low_wage['Value'].std()]

# %%
# Put your code here:

#access values
values = low_wage_value['Value']
#access wage
wages = low_wage_value['Wage']
#create scatter plot
colors = [i for i in range (low_wage_value.shape[0])]
plt.scatter(wages, values, s = 50, c=colors, cmap = 'rainbow')
plt.colorbar()
plt.xlabel('Wages')
plt.ylabel('Values')
plt.title('Scatter Plot for High Value, Underpaid Players')

plt.savefig('high-value-underpaid-players.jpg', format='jpeg') # save image
plt.show()

# %%
player_high_value_low_wage = filtered_df[(filtered_df['Value'] > filtered_df['Value'].std()) | (filtered_df['Wage'] < filtered_df['Wage'].std())]

# %%
player_high_value_low_wage.describe()
# Out:
#               Value           Wage
# count  1.762800e+04   17628.000000
# mean   2.835526e+06    7822.952122
# std    7.948519e+06   19367.988674
# min    9.000000e+03     500.000000
# 25%    4.500000e+05    1000.000000
# 50%    9.000000e+05    3000.000000
# 75%    1.800000e+06    7000.000000
# max    1.855000e+08  560000.000000

# %%
q1 = player_high_value_low_wage['Value'].quantile(0.25)
q3 = player_high_value_low_wage['Value'].quantile(0.75)
iqr = q3 - q1

# %%
lower = q1 - 1.5*iqr
upper = q1 + 1.5*iqr
lower, upper
# Out:
# (-1575000.0, 2475000.0)

# %%
filtered_df.sort_values('Value', ascending=False)
# Out:
#                    Name      Value    Wage
# 8             K. Mbappé  185500000  160000
# 4             Neymar Jr  132000000  270000
# 3          K. De Bruyne  129000000  370000
# 29            J. Sancho  124000000   82000
# 65           K. Havertz  121000000  105000
# ...                 ...        ...     ...
# 16236         A. García      25000     500
# 17073  K. Stamatopoulos      20000     600
# 17863        Sun Shoubo      15000     900
# 17404        B. Gommert      15000     500
# 18431          G. Maley       9000     600
#
# [18731 rows x 3 columns]

# %%
filtered_df.describe()
# Out:
#               Value           Wage
# count  1.873100e+04   18731.000000
# mean   2.902997e+06    9210.026160
# std    7.728745e+06   19809.484584
# min    9.000000e+03     500.000000
# 25%    4.750000e+05    1000.000000
# 50%    9.750000e+05    3000.000000
# 75%    2.000000e+06    9000.000000
# max    1.855000e+08  560000.000000

# %%
a = 1
b = 2
c = a + b
c
# Out:
# 3
